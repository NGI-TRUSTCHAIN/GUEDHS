# %%
import syft as sy

# %%
chuc_client = sy.login(port=8081, email="info@openmined.org", password="changethis")
chudsa_client = sy.login(port=8082, email="info@openmined.org", password="changethis")
# Out:
# Logged into <festive_gardner: High side Domain> as <info@openmined.org>
# ...
# Logged into <agitated_koller: High side Domain> as <info@openmined.org>
# ...

# %%
import pandas as pd
datasets = chuc_client.datasets.get_all()
list(datasets.items())[0][1]
# Out:
# ...
# syft.service.dataset.dataset.Dataset

# %%
# Out:
# ('syft_node_location', <UID: 28d2428661e04555abcda20764aa6c8f>)
# ('syft_client_verify_key', 62f2c63fc10c0c794b72b3eb78871b7bceed7babac50bdecdd88556c47a5df73)
# ('id', <UID: eff6d8fc359b44349816ca0482c937ce>)
# ('name', 'RSV Dataset')
# ('node_uid', <UID: 28d2428661e04555abcda20764aa6c8f>)
# ('asset_list', [syft.service.dataset.dataset.Asset])
# ('contributors', {syft.service.dataset.dataset.Contributor})
# ('citation', None)
# ('url', None)
# ('description', syft.service.dataset.dataset.MarkdownDescription)
# ('updated_at', 'Apr 15, 2024')
# ('requests', 0)
# ('mb_size', 0.8613405227661133)
# ('created_at', syft.types.datetime.DateTime)
# ('uploader', syft.service.dataset.dataset.Contributor)

# %%
pd.DataFrame([{k: v for k, v in dataset} for dataset in datasets])
# Out:
#                  syft_node_location  \
# 0  28d2428661e04555abcda20764aa6c8f
#
#                               syft_client_verify_key  \
# 0  62f2c63fc10c0c794b72b3eb78871b7bceed7babac50bd...
#
#                                  id         name  \
# 0  eff6d8fc359b44349816ca0482c937ce  RSV Dataset
#
#                            node_uid                            asset_list  \
# 0  28d2428661e04555abcda20764aa6c8f  [syft.service.dataset.dataset.Asset]
#
#                                  contributors citation   url  \
# 0  {syft.service.dataset.dataset.Contributor}     None  None
#
#                                         description    updated_at  requests  \
# 0  syft.service.dataset.dataset.MarkdownDescription  Apr 15, 2024         0
#
#     mb_size           created_at                                  uploader
# 0  0.861341  2024-04-15 15:32:34  syft.service.dataset.dataset.Contributor

# %%
gateway_client = sy.login(port=8083, email="info@openmined.org", password="changethis")
# Out:
# Logged into <amazing_thrun: High side Gateway> as <info@openmined.org>
# ...

# %%
chuc_client.connect_to_gateway(via_client=gateway_client)
chudsa_client.connect_to_gateway(via_client=gateway_client)
# Out:
# ...
# SyftSuccess: Connected domain to amazing_thrun gateway

# %%
gateway_client.domains
# Out:
# syft.client.gateway_client.ProxyClient

# %%
chuc_client.register(name="data_scientist", email="data.scientist@min-saude.pt", password="password", password_verify="password")
chudsa_client.register(name="data_scientist", email="data.scientist@min-saude.pt", password="password", password_verify="password")
# Out:
# ...
# SyftError: User already exists with email: data.scientist@min-saude.pt

# %%
chuc_client.users
# Out:
# <style>
#   body[data-jp-theme-light='false'] {
#         --primary-color: #111111;
#         --secondary-color: #212121;
#         --tertiary-color: #CFCDD6;
#         --button-color: #111111;
#   }
#
#   body {
#         --primary-color: #ffffff;
#         --secondary-color: #f5f5f5;
#         --tertiary-color: #000000de;
#         --button-color: #d1d5db;
#   }
#
#   .header-1 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 2.0736em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-2 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 1.728em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-3 {
#         font-style: normal;
#         font-weight: 600;
#         font-size:  1.44em;
#         line-height: 100%;
#         leading-trim: both;
# ...

# %%
chudsa_client.users
# Out:
# <style>
#   body[data-jp-theme-light='false'] {
#         --primary-color: #111111;
#         --secondary-color: #212121;
#         --tertiary-color: #CFCDD6;
#         --button-color: #111111;
#   }
#
#   body {
#         --primary-color: #ffffff;
#         --secondary-color: #f5f5f5;
#         --tertiary-color: #000000de;
#         --button-color: #d1d5db;
#   }
#
#   .header-1 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 2.0736em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-2 {
#         font-style: normal;
#         font-weight: 600;
#         font-size: 1.728em;
#         line-height: 100%;
#         leading-trim: both;
#         text-edge: cap;
#         color: #17161D;
#     }
#
#   .header-3 {
#         font-style: normal;
#         font-weight: 600;
#         font-size:  1.44em;
#         line-height: 100%;
#         leading-trim: both;
# ...

# %%
chuc_client.connection
# Out:
# HTTPConnection: http://localhost:8081
